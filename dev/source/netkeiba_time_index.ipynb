# %%
from pathlib import Path
from netkeiba_time_index import get_csv_netkeiba_time_index

# %%
# フォルダ内のすべての .html ファイルを取得（フルパス）
folder_path = "C:/Users/betashort/Documents/GitHub/KEIBA/dev/data/20250803/"

# %%
folder = Path(folder_path)
html_files = list(folder.rglob("*.html"))

# %%
html_files[0].with_suffix("")
# Out:
# WindowsPath('C:/Users/betashort/Documents/GitHub/KEIBA/dev/data/20250803/20250803chukyo6R')

# %%
for path in html_files:
    
    get_csv_netkeiba_time_index(path.with_suffix(""))
